# %% [markdown]
# # BERT for Classification
#
# Fine-tune a pre-trained **BERT** model to classify movie reviews as positive or negative.
#
# BERT reads the full sentence in both directions to understand context — much more powerful than simple word counting.

# %%
# !pip install transformers tensorflow --quiet

# %%
from transformers import BertTokenizer, TFBertForSequenceClassification
import tensorflow as tf

texts = [
    'I loved this movie! It was amazing.',
    'This was the worst film I have ever seen.',
    'An enjoyable experience with great acting.',
    'Awful plot and bad dialogue.',
    'Brilliant storytelling and stunning visuals.',
    'Boring and predictable from start to finish.',
]
labels = [1, 0, 1, 0, 1, 0]  # 1=positive, 0=negative

# 1. Load the BERT tokenizer for 'bert-base-uncased'
tokenizer = 

# 2. Tokenize the texts
#    Use truncation=True, padding=True, max_length=32, return_tensors='tf'
encodings = 

dataset = tf.data.Dataset.from_tensor_slices((dict(encodings), labels)).batch(2)

# 3. Load TFBertForSequenceClassification with num_labels=2
model = 

# 4. Compile and fine-tune for 2 epochs
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=2e-5),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)
history = model.fit(dataset, epochs=2)

loss, accuracy = model.evaluate(dataset, verbose=0)
print(f'Accuracy: {accuracy*100:.1f}%')

# %%
assert accuracy > 0.5, 'Should achieve > 50% accuracy'
assert loss > 0
assert len(history.history['loss']) == 2, 'Should train for 2 epochs'
print('✓ All tests passed!')
