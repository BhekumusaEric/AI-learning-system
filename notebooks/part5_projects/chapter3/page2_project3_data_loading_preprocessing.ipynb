# %% [markdown]
# # Project 3: CNN Classification — Data Loading & Preprocessing
#
# Load the **Fashion-MNIST** dataset, normalise pixel values, reshape for CNN input, and create a train/validation/test split.

# %%
# !pip install tensorflow matplotlib --quiet

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

np.random.seed(42)

class_names = ['T-shirt/top','Trouser','Pullover','Dress','Coat',
               'Sandal','Shirt','Sneaker','Bag','Ankle boot']

# 1. Load Fashion-MNIST
(X_full, y_full), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()
print(f'Loaded: X_full={X_full.shape}, X_test={X_test.shape}')

# 2. Normalise pixel values to [0, 1]
X_full = 
X_test  = 

# 3. Reshape to add channel dimension: (N, 28, 28) → (N, 28, 28, 1)
X_full = 
X_test  = 

# 4. Split X_full/y_full into train (90%) and validation (10%)
#    Use train_test_split with test_size=0.1, random_state=42, stratify=y_full
X_train, X_val, y_train, y_val = 

print(f'Train: {X_train.shape}, Val: {X_val.shape}, Test: {X_test.shape}')

# 5. Visualise 10 sample images
fig, axes = plt.subplots(2, 5, figsize=(12, 5))
for i, ax in enumerate(axes.flat):
    ax.imshow(X_train[i, :, :, 0], cmap='gray')
    ax.set_title(class_names[y_train[i]])
    ax.axis('off')
plt.tight_layout()
plt.show()

# %%
assert X_train.max() <= 1.0 and X_train.min() >= 0.0, 'Pixels should be normalised to [0,1]'
assert X_train.shape[-1] == 1, 'Should have channel dimension'
assert len(X_val) > 0, 'Validation set should not be empty'
print('✓ All tests passed!')
